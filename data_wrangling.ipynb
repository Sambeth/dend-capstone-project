# %%
import configparser

from pyspark.sql import SparkSession
from pyspark.sql.types import (
    StructField,
    StructType,
    StringType,
    DoubleType,
    IntegerType
)
import pyspark.sql.functions as f
from pyspark.sql.functions import udf, monotonically_increasing_id

# %%
spark = SparkSession.builder\
            .master('local')\
            .appName('general_practices')\
            .getOrCreate()

# %%
config = configparser.ConfigParser()
config.read('dl.cfg')

access_key_id = config.get('CREDENTIALS', 'AWS_ACCESS_KEY_ID')
secret_key_id = config.get('CREDENTIALS', 'AWS_SECRET_ACCESS_KEY')

# %%
spark.sparkContext._jsc.hadoopConfiguration().set("fs.s3a.access.key",access_key_id)
spark.sparkContext._jsc.hadoopConfiguration().set("fs.s3a.secret.key", secret_key_id)

# %%
# files
chemicals_file = 'data/chem_subs.csv'
practices_file = 'data/practices.csv'
practice_prescribing_file = 'data/practice_prescribing.csv'
practice_size_file = 'data/practice_list_size_and_gp_count.csv'
bnf_codes_file = 'data/bnf_codes.csv'

# %%
# schema settings for datasets
practice_prescribing_schema = StructType([
    StructField("SHA", StringType(), True),
    StructField("PCT", StringType(), True),
    StructField("PRACTICE", StringType(), True),
    StructField("BNF_CODE", StringType(), True),
    StructField("BNF_NAME", StringType(), True),
    StructField("ITEMS", IntegerType(), True),
    StructField("NIC", DoubleType(), True),
    StructField("ACT_COST", DoubleType(), True),
    StructField("QUANTITY", IntegerType(), True),
    StructField("PERIOD", StringType(), True),
])

chemicals_schema = StructType([
    StructField("CHEM_SUB_CODE", StringType(), True),
    StructField("NAME", StringType(), True),
])

practices_schema = StructType([
    StructField("PERIOD", StringType(), True),
    StructField("PRACTICE_CODE", StringType(), True),
    StructField("PRACTICE_NAME", StringType(), True),
    StructField("ADDRESS_1", StringType(), True),
    StructField("ADDRESS_2", StringType(), True),
    StructField("ADDRESS_3", StringType(), True),
    StructField("ADDRESS_4", StringType(), True),
    StructField("POSTCODE", StringType(), True),
])

practice_size_schema = StructType([
    StructField("COMM_PROV", StringType(), True),
    StructField("GROUP_CODE", StringType(), True),
    StructField("PRACTICE_NAME", StringType(), True),
    StructField("PRACTICE_ADDRESS", StringType(), True),
    StructField("PRACTICE_CODE", StringType(), True),
    StructField("GP_COUNT", IntegerType(), True),
    StructField("DISPENSING_LIST_SIZE", IntegerType(), True),
    StructField("PRESCRIBING_LIST_SIZE", IntegerType(), True),
    StructField("TOTAL_LIST_SIZE", IntegerType(), True),
])

bnf_codes_schema = StructType([
    StructField("BNF_CHAPTER", StringType(), True),
    StructField("BNF_CHAPTER_CODE", StringType(), True),
    StructField("BNF_SECTION", StringType(), True),
    StructField("BNF_SECTION_CODE", StringType(), True),
    StructField("BNF_PARAGRAPH", StringType(), True),
    StructField("BNF_PARAGRAPH_CODE", StringType(), True),
    StructField("BNF_SUBPARAGRAPH", StringType(), True),
    StructField("BNF_SUBPARAGRAPH_CODE", StringType(), True),
    StructField("BNF_CHEMICAL_SUBSTANCE", StringType(), True),
    StructField("BNF_CHEMICAL_SUBSTANCE_CODE", StringType(), True),
    StructField("BNF_PRODUCT", StringType(), True),
    StructField("BNF_PRODUCT_CODE", StringType(), True),
    StructField("BNF_PRESENTATION", StringType(), True),
    StructField("BNF_PRESENTATION_CODE", StringType(), True),
])

# %%
get_year = udf(lambda x: int(x[:-2]) if x else None, IntegerType())
get_month = udf(lambda x: int(x[-2:]) if x else None, IntegerType())

get_chapter = udf(lambda x: x[:2] if x else None)
get_section = udf(lambda x: x[:4] if x else None)
get_paragraph = udf(lambda x: x[:6] if x else None)
get_sub_paragraph = udf(lambda x: x[:7] if x else None)
get_chemical = udf(lambda x: x[:9] if x else None)
get_product = udf(lambda x: x[:11] if x else None)

# %% [markdown]
# ## CHEMICALS TABLE

# %%
chemicals = spark.read.csv(chemicals_file, header=True, schema=chemicals_schema)

# %%
chemicals = chemicals.withColumn("CHAPTER_CODE", get_chapter(chemicals['CHEM_SUB_CODE']))
chemicals = chemicals.withColumn("SECTION_CODE", get_section(chemicals['CHEM_SUB_CODE']))
chemicals = chemicals.withColumn("PRARGRAPH_CODE", get_paragraph(chemicals['CHEM_SUB_CODE']))
chemicals = chemicals.withColumn("SUB_PARAGRAPH_CODE", get_sub_paragraph(chemicals['CHEM_SUB_CODE']))

# %%
chemicals.show(3)
# Out:
# +-------------+--------------------+------------+------------+--------------+------------------+
# |CHEM_SUB_CODE|                NAME|CHAPTER_CODE|SECTION_CODE|PRARGRAPH_CODE|SUB_PARAGRAPH_CODE|
# +-------------+--------------------+------------+------------+--------------+------------------+
# |    010101000|Other Antacid & S...|          01|        0101|        010101|           0101010|
# |    0101010A0|     Alexitol Sodium|          01|        0101|        010101|           0101010|
# |    0101010B0|          Almasilate|          01|        0101|        010101|           0101010|
# +-------------+--------------------+------------+------------+--------------+------------------+
# only showing top 3 rows

# %%
# path = 's3a://capstone-health/staging/' + 'chemicals.parquet'
# pathy = 'chemicals.parquet'
# print(path)
# chemicals.write.parquet(path, mode='overwrite')

# %% [markdown]
# ## PRACTICES TABLE

# %%
practices = spark.read.csv(practices_file, header=False, schema=practices_schema)

# %%
practices = practices.withColumn("YEAR", get_year(practices.PERIOD))
practices = practices.withColumn("MONTH", get_month(practices.PERIOD))

# %%
practices = practices.drop('PERIOD')

# %%
practices.schema
# Out:
# StructType(List(StructField(PRACTICE_CODE,StringType,true),StructField(PRACTICE_NAME,StringType,true),StructField(ADDRESS_1,StringType,true),StructField(ADDRESS_2,StringType,true),StructField(ADDRESS_3,StringType,true),StructField(ADDRESS_4,StringType,true),StructField(POSTCODE,StringType,true),StructField(YEAR,IntegerType,true),StructField(MONTH,IntegerType,true)))

# %%
practices.show(3)
# Out:
# +-------------+--------------------+--------------------+-------------+----------------+---------+--------+----+-----+
# |PRACTICE_CODE|       PRACTICE_NAME|           ADDRESS_1|    ADDRESS_2|       ADDRESS_3|ADDRESS_4|POSTCODE|YEAR|MONTH|
# +-------------+--------------------+--------------------+-------------+----------------+---------+--------+----+-----+
# |       A81001| THE DENSHAM SURGERY|   THE HEALTH CENTRE|LAWSON STREET|STOCKTON-ON-TEES|CLEVELAND|TS18 1HU|2018|   12|
# |       A81002|QUEENS PARK MEDIC...|QUEENS PARK MEDIC...|FARRER STREET|STOCKTON ON TEES|CLEVELAND|TS18 2AW|2018|   12|
# |       A81004|BLUEBELL MEDICAL ...|      TRIMDON AVENUE|       ACKLAM|   MIDDLESBROUGH|      N/A| TS5 8SB|2018|   12|
# +-------------+--------------------+--------------------+-------------+----------------+---------+--------+----+-----+
# only showing top 3 rows

# %% [markdown]
# ## LINK THIS TO PRACTICES FOR MORE INFORMATION ABOUT PRACTICES

# %%
practice_size_and_group = spark.read.csv(practice_size_file, header=True, schema=practice_size_schema)

# %%
practice_groups = practice_size_and_group.select(
    'GROUP_CODE',
    'COMM_PROV',
).dropDuplicates()
practice_groups = practice_groups.na.drop(subset=["GROUP_CODE"])

# %%
practice_groups.show(5)
# Out:
# +----------+--------------------+
# |GROUP_CODE|           COMM_PROV|
# +----------+--------------------+
# |     RQX00|HOMERTON UNIV HPL...|
# |     RWK00|EAST LONDON NHS F...|
# |     NLG00|COMMUNITAS CLINIC...|
# |     Q6200|NORTH WEST LONDON...|
# |     NLO00|              VOCARE|
# +----------+--------------------+
# only showing top 5 rows

# %%
practice_size = practice_size_and_group.select(
    'PRACTICE_CODE',
    'GROUP_CODE',
    'GP_COUNT',
    'DISPENSING_LIST_SIZE',
    'PRESCRIBING_LIST_SIZE',
    'TOTAL_LIST_SIZE'
)
practice_size = practice_size.na.drop(subset=["PRACTICE_CODE"])

# %%
practice_size.show(5)
# Out:
# +-------------+----------+--------+--------------------+---------------------+---------------+
# |PRACTICE_CODE|GROUP_CODE|GP_COUNT|DISPENSING_LIST_SIZE|PRESCRIBING_LIST_SIZE|TOTAL_LIST_SIZE|
# +-------------+----------+--------+--------------------+---------------------+---------------+
# |       Y05205|     NI300|       2|                null|                 null|           null|
# |       Y00898|     NI300|      37|                null|                 null|           null|
# |       Y05727|     NI300|       2|                null|                 null|           null|
# |       Y06182|     NI300|       1|                null|                 null|           null|
# |       Y06053|     NI300|       1|                null|                 null|           null|
# +-------------+----------+--------+--------------------+---------------------+---------------+
# only showing top 5 rows

# %% [markdown]
# ## PRESCRIBING FACTS TABLE

# %%
practice_prescribing = spark.read.csv(practice_prescribing_file, header=True, schema=practice_prescribing_schema)

# %%
practice_prescribing = practice_prescribing.withColumn("PRESCRIPTION_ID", monotonically_increasing_id())

# %%
practice_prescribing = practice_prescribing.withColumn("YEAR", get_year(practice_prescribing.PERIOD))
practice_prescribing = practice_prescribing.withColumn("MONTH", get_month(practice_prescribing.PERIOD))
practice_prescribing = practice_prescribing.drop('PERIOD')
practice_prescribing = practice_prescribing.withColumn("BNF_CHAPTER_CODE", get_chapter(practice_prescribing['BNF_CODE']))
practice_prescribing = practice_prescribing.withColumn("BNF_SECTION_CODE", get_section(practice_prescribing['BNF_CODE']))
practice_prescribing = practice_prescribing.withColumn("BNF_PARAGRAPH_CODE", get_paragraph(practice_prescribing['BNF_CODE']))
practice_prescribing = practice_prescribing.withColumn("BNF_SUBPARAGRAPH_CODE", get_sub_paragraph(practice_prescribing['BNF_CODE']))
practice_prescribing = practice_prescribing.withColumn("BNF_CHEMICAL_CODE", get_chemical(practice_prescribing['BNF_CODE']))
practice_prescribing = practice_prescribing.withColumn("BNF_PRODUCT_CODE", get_product(practice_prescribing['BNF_CODE']))

# %%
practice_prescribing.limit(20).toPandas()
# Out:
#     SHA  PCT PRACTICE         BNF_CODE  \
# 0   Q44  01C   N81002  0101021B0AAALAL
# 1   Q44  01C   N81002  0101021B0AAAPAP
# 2   Q44  01C   N81002  0101021B0BEACAH
# 3   Q44  01C   N81002  0101021B0BEADAJ
# 4   Q44  01C   N81002  0101021B0BEAIAL
# 5   Q44  01C   N81002  0101021B0BEBEAL
# 6   Q44  01C   N81002  0102000L0AAACAC
# 7   Q44  01C   N81002  0102000N0AAABAB
# 8   Q44  01C   N81002  0102000N0BBAAAB
# 9   Q44  01C   N81002  0102000P0AAABAB
# 10  Q44  01C   N81002  0102000P0AAADAD
# 11  Q44  01C   N81002  0102000P0BCAEAD
# 12  Q44  01C   N81002  0102000T0AAAAAA
# 13  Q44  01C   N81002  0102000X0AAAAAA
# 14  Q44  01C   N81002  0102000Y0AAAFAF
# 15  Q44  01C   N81002  0103010D0AAABAB
# 16  Q44  01C   N81002  0103010T0AAAAAA
# 17  Q44  01C   N81002  0103010T0AAACAC
# 18  Q44  01C   N81002  0103010T0AAAEAE
# 19  Q44  01C   N81002  0103050E0AAAAAA
#
#                                     BNF_NAME  ITEMS     NIC  ACT_COST  \
# 0              Sod Algin/Pot Bicarb_Susp S/F      1   10.24      9.52
# 1    Sod Alginate/Pot Bicarb_Tab Chble 500mg      1    3.07      2.86
# 2           Gaviscon_Liq Orig Aniseed Relief      1   12.99     12.07
# 3    Gaviscon Infant_Sach 2g (Dual Pack) S/F      3   81.94     76.09
# 4   Gaviscon Advance_Liq (Aniseed) (Reckitt)     11   55.29     51.76
# 5      Gaviscon Advance_Liq (Peppermint) S/F      3   10.24      9.64
# 6                Glycopyrronium Brom_Tab 1mg      1  430.66    399.84
# 7                Hyoscine Butylbrom_Tab 10mg     12   54.11     50.57
# 8                          Buscopan_Tab 10mg      4   19.50     18.25
# 9                   Mebeverine HCl_Tab 135mg      6   17.87     17.16
# 10              Mebeverine HCl_Cap 200mg M/R     22  163.90    153.30
# 11                      Colofac MR_Cap 200mg      1    6.92      6.44
# 12              Peppermint Oil_Cap E/C 0.2ml      5   34.19     32.00
# 13  Ispag/Mebeverine_Gran Eff 3.5g/135mg S/F      1   25.98     24.23
# 14               Propantheline Brom_Tab 15mg      1   15.56     14.55
# 15                      Cimetidine_Tab 400mg      1   31.84     29.57
# 16                  Ranitidine HCl_Tab 150mg     45   49.18     48.51
# 17                  Ranitidine HCl_Tab 300mg     10   16.56     15.79
# 18     Ranitidine HCl_Oral Soln 75mg/5ml S/F      3   10.19      9.70
# 19                 Esomeprazole_Tab E/C 20mg     18   46.84     44.10
#
#     QUANTITY  PRESCRIPTION_ID  YEAR  MONTH BNF_CHAPTER_CODE BNF_SECTION_CODE  \
# 0       1000                0  2018     12               01             0101
# 1         60                1  2018     12               01             0101
# 2        900                2  2018     12               01             0101
# 3        255                3  2018     12               01             0101
# 4       5400                4  2018     12               01             0101
# 5       1000                5  2018     12               01             0101
# 6         56                6  2018     12               01             0102
# 7       1010                7  2018     12               01             0102
# 8        364                8  2018     12               01             0102
# 9        424                9  2018     12               01             0102
# 10      1208               10  2018     12               01             0102
# 11        60               11  2018     12               01             0102
# 12       408               12  2018     12               01             0102
# 13        56               13  2018     12               01             0102
# 14        84               14  2018     12               01             0102
# 15       120               15  2018     12               01             0103
# 16      2566               16  2018     12               01             0103
# 17       502               17  2018     12               01             0103
# 18       500               18  2018     12               01             0103
# 19       588               19  2018     12               01             0103
#
#    BNF_PARAGRAPH_CODE BNF_SUBPARAGRAPH_CODE BNF_CHEMICAL_CODE BNF_PRODUCT_CODE
# 0              010102               0101021         0101021B0      0101021B0AA
# 1              010102               0101021         0101021B0      0101021B0AA
# 2              010102               0101021         0101021B0      0101021B0BE
# 3              010102               0101021         0101021B0      0101021B0BE
# 4              010102               0101021         0101021B0      0101021B0BE
# 5              010102               0101021         0101021B0      0101021B0BE
# 6              010200               0102000         0102000L0      0102000L0AA
# 7              010200               0102000         0102000N0      0102000N0AA
# 8              010200               0102000         0102000N0      0102000N0BB
# 9              010200               0102000         0102000P0      0102000P0AA
# 10             010200               0102000         0102000P0      0102000P0AA
# 11             010200               0102000         0102000P0      0102000P0BC
# 12             010200               0102000         0102000T0      0102000T0AA
# 13             010200               0102000         0102000X0      0102000X0AA
# 14             010200               0102000         0102000Y0      0102000Y0AA
# 15             010301               0103010         0103010D0      0103010D0AA
# 16             010301               0103010         0103010T0      0103010T0AA
# 17             010301               0103010         0103010T0      0103010T0AA
# 18             010301               0103010         0103010T0      0103010T0AA
# 19             010305               0103050         0103050E0      0103050E0AA

# %% [markdown]
# ## BNF CHAPTER, SECTION, PARAGRAPH, SUBPARAGRAPH, PRODUCT, PRESENTATION TABLES

# %%
bnf_codes = spark.read.csv(bnf_codes_file, header=True, schema=bnf_codes_schema)

# %%
bnf_chapters = bnf_codes.select('BNF_CHAPTER_CODE', 'BNF_CHAPTER').dropDuplicates()
bnf_sections = bnf_codes.select('BNF_SECTION_CODE', 'BNF_SECTION').dropDuplicates()
bnf_paragraphs = bnf_codes.select('BNF_PARAGRAPH_CODE', 'BNF_PARAGRAPH').dropDuplicates()
bnf_subparagraph = bnf_codes.select('BNF_SUBPARAGRAPH_CODE', 'BNF_SUBPARAGRAPH').dropDuplicates()
bnf_chemicals = bnf_codes.select('BNF_CHEMICAL_SUBSTANCE_CODE', 'BNF_CHEMICAL_SUBSTANCE').dropDuplicates()
bnf_products = bnf_codes.select('BNF_PRODUCT_CODE', 'BNF_PRODUCT').dropDuplicates()
bnf_presentations = bnf_codes.select('BNF_PRESENTATION_CODE', 'BNF_PRESENTATION').dropDuplicates()

# %%
bnf_presentations.limit(20).toPandas()
# Out:
#    BNF_PRESENTATION_CODE                       BNF_PRESENTATION
# 0        0101010I0AAAJAJ                        Mag Ox_Cap 10mg
# 1        010102100AAAIAI    Bism Subsalic_Tab 262.5mg Chble S/F
# 2        0102000H0BFAAA0                       Actonorm Sed_Gel
# 3        0102000N0AAANAN  Hyoscine Butylbrom_Liq Spec 4.9mg/5ml
# 4        0103050P0AAARAR           Omeprazole_Liq Spec 25mg/5ml
# 5        0107010N0AAADAD                      Gppe Crm_Hemocane
# 6        0202010D0AAAQAQ                     Chloroth_Cap 100mg
# 7        0202010F0AAACAC                Chlortalidone_Tab 500mg
# 8        0202010L0AAAHAH             Hydchloroth_Oral Liq @spec
# 9        0202030S0AAA5A5             Spironol_Susp 10mg/5ml S/F
# 10       0202040T0AAAAAA      Spironol/Furosemide_Cap 50mg/20mg
# 11       0204000R0AADEDE      Propranolol HCl_Liq Spec 16mg/5ml
# 12       0205010J0AAARAR          Hydralazine HCl_Susp 25mg/5ml
# 13       0205051F0AADHDH                    Captopril_Cap 7.5mg
# 14       0205051J0BDAAAA                       Fozitec_Tab 10mg
# 15       0205051V0BBAAAA                              Tarka_Cap
# 16       0206010F0AAACAC             Glyceryl Trinit_Patch 25mg
# 17       0206010F0BPAAA0                       Lenitral 7.5_Cap
# 18       0206010K0BCACAF                 Modisal LA 50_Cap 50mg
# 19       0206020R0AAATAT           Nifedipine_Liq Spec 10mg/5ml

# %%
practice_prescribing.filter("BNF_CODE = '0202040T0AAAAAA'").collect()
# Out:
# [Row(SHA='Q44', PCT='01C', PRACTICE='N81070', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=20430, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q44', PCT='02D', PRACTICE='N81051', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=68155, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q44', PCT='02D', PRACTICE='N81127', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=80035, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q44', PCT='02F', PRACTICE='N81006', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=3.99, ACT_COST=3.82, QUANTITY=14, PRESCRIPTION_ID=120082, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q44', PCT='12F', PRACTICE='N85027', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=199448, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q45', PCT='00C', PRACTICE='A83040', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=6, NIC=31.9, ACT_COST=30.08, QUANTITY=112, PRESCRIPTION_ID=247847, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q45', PCT='00D', PRACTICE='A83019', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=268654, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q45', PCT='00J', PRACTICE='A83014', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=7, NIC=28.47, ACT_COST=26.91, QUANTITY=100, PRESCRIPTION_ID=314662, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q45', PCT='00J', PRACTICE='A83027', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=31.88, ACT_COST=29.62, QUANTITY=112, PRESCRIPTION_ID=327646, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q45', PCT='00K', PRACTICE='A81014', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=363957, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q45', PCT='00K', PRACTICE='A81027', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=368310, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q45', PCT='00M', PRACTICE='A81030', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=423706, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q46', PCT='00V', PRACTICE='P83020', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=534475, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q46', PCT='00Y', PRACTICE='Y01124', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=602798, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q46', PCT='01G', PRACTICE='P87032', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=678646, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q46', PCT='02A', PRACTICE='P91003', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=817001, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q46', PCT='02A', PRACTICE='P91019', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=836835, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q46', PCT='02H', PRACTICE='P92007', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=870226, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q47', PCT='00Q', PRACTICE='P81051', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=1062729, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q47', PCT='00R', PRACTICE='P81714', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=1118366, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q47', PCT='00X', PRACTICE='P81117', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=1134655, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q47', PCT='01A', PRACTICE='P81025', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=1163044, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q47', PCT='01A', PRACTICE='P81137', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=1194554, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q47', PCT='01E', PRACTICE='P81067', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=8589971960, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q47', PCT='02M', PRACTICE='P81037', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=8590072655, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q48', PCT='01X', PRACTICE='N83624', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=3, NIC=23.91, ACT_COST=22.23, QUANTITY=84, PRESCRIPTION_ID=8590259717, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q48', PCT='99A', PRACTICE='N82049', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=8590298646, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q50', PCT='02Y', PRACTICE='B81029', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=8590704121, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q50', PCT='02Y', PRACTICE='B81061', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=8590718702, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q50', PCT='02Y', PRACTICE='B81101', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=8590734556, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q50', PCT='03D', PRACTICE='B82035', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=8590752055, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q52', PCT='03A', PRACTICE='B85006', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=17180151940, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q52', PCT='15F', PRACTICE='B86055', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=17180363442, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q53', PCT='05A', PRACTICE='Y04951', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=17180512758, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q53', PCT='05A', PRACTICE='Y04952', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=17180513539, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q53', PCT='05F', PRACTICE='M81026', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=17180524769, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q53', PCT='05H', PRACTICE='M84037', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=17180562526, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q53', PCT='05T', PRACTICE='M81029', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=17180666909, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q54', PCT='05C', PRACTICE='M87026', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=17180757784, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q54', PCT='05Y', PRACTICE='M91019', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=17180901685, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q54', PCT='05Y', PRACTICE='M91641', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=17180933530, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q54', PCT='06A', PRACTICE='Y02636', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=17180994690, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q54', PCT='15E', PRACTICE='M85013', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=17181008367, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q54', PCT='15E', PRACTICE='M85046', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=19.36, ACT_COST=18.09, QUANTITY=68, PRESCRIPTION_ID=17181038877, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q54', PCT='15E', PRACTICE='M85061', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=17181054886, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q54', PCT='15E', PRACTICE='M89010', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=25769922002, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q55', PCT='04K', PRACTICE='C84039', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=25770111305, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q56', PCT='06H', PRACTICE='D81637', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=25770418371, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q56', PCT='06L', PRACTICE='D83024', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=25770447093, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q56', PCT='06L', PRACTICE='D83039', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=3, NIC=39.85, ACT_COST=37.03, QUANTITY=140, PRESCRIPTION_ID=25770455129, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q56', PCT='06L', PRACTICE='Y01794', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=25770494205, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q56', PCT='06M', PRACTICE='D83009', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=25770509419, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q56', PCT='06M', PRACTICE='D83047', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=31.88, ACT_COST=29.6, QUANTITY=112, PRESCRIPTION_ID=25770524849, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q56', PCT='06V', PRACTICE='D82004', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=4, NIC=15.96, ACT_COST=15.26, QUANTITY=56, PRESCRIPTION_ID=25770531751, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q56', PCT='06W', PRACTICE='D82071', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=25770584422, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q56', PCT='07J', PRACTICE='D82049', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.4, QUANTITY=28, PRESCRIPTION_ID=25770645622, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q57', PCT='06Q', PRACTICE='F81683', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=5, NIC=21.91, ACT_COST=20.7, QUANTITY=77, PRESCRIPTION_ID=25770762419, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q57', PCT='06T', PRACTICE='F81221', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=25770814625, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q57', PCT='06T', PRACTICE='F81679', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=25770820913, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q57', PCT='99F', PRACTICE='F81096', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=25770980593, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q58', PCT='04G', PRACTICE='K83026', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=34359848416, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q58', PCT='04G', PRACTICE='K83037', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=3.99, ACT_COST=3.82, QUANTITY=14, PRESCRIPTION_ID=34359864143, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q58', PCT='04G', PRACTICE='K83042', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=34359871170, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q58', PCT='06F', PRACTICE='E81057', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=34359968192, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q58', PCT='06K', PRACTICE='E82019', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=9, NIC=23.89, ACT_COST=23.09, QUANTITY=84, PRESCRIPTION_ID=34359997629, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q58', PCT='06N', PRACTICE='E82001', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=34360074559, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q59', PCT='04Q', PRACTICE='C83649', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.4, QUANTITY=28, PRESCRIPTION_ID=34360417812, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q59', PCT='04V', PRACTICE='C82043', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=23.91, ACT_COST=22.22, QUANTITY=84, PRESCRIPTION_ID=34360442217, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q60', PCT='05G', PRACTICE='M83121', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=34360600697, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q60', PCT='05G', PRACTICE='M83723', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=34360611573, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q60', PCT='05V', PRACTICE='M83009', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=34360711381, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q60', PCT='05V', PRACTICE='M83052', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=23.91, ACT_COST=22.21, QUANTITY=84, PRESCRIPTION_ID=34360727076, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='07L', PRACTICE='F82038', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=3, NIC=31.88, ACT_COST=29.63, QUANTITY=112, PRESCRIPTION_ID=34360830359, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='07M', PRACTICE='E83018', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=34360872503, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='07R', PRACTICE='F83632', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=42949691204, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='07X', PRACTICE='F85678', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=42949781310, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='08F', PRACTICE='F82011', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=3, NIC=31.88, ACT_COST=29.63, QUANTITY=112, PRESCRIPTION_ID=42949845494, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='08M', PRACTICE='F84121', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=42949948333, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='08M', PRACTICE='F84669', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=42949956846, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='08M', PRACTICE='F84670', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=42949958132, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='08N', PRACTICE='F86020', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=7.98, ACT_COST=7.63, QUANTITY=28, PRESCRIPTION_ID=42949985900, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='08N', PRACTICE='F86025', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42949989852, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='08N', PRACTICE='F86085', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950004260, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='08N', PRACTICE='F86731', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950019208, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q61', PCT='08W', PRACTICE='F86638', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950094678, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q62', PCT='07P', PRACTICE='E84665', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=23.91, ACT_COST=22.21, QUANTITY=84, PRESCRIPTION_ID=42950154545, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q62', PCT='08E', PRACTICE='E84022', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=42950326268, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q62', PCT='08G', PRACTICE='E86003', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=1.99, ACT_COST=1.96, QUANTITY=7, PRESCRIPTION_ID=42950360193, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q62', PCT='08G', PRACTICE='E86027', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950383259, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='07N', PRACTICE='G83004', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950479217, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='07N', PRACTICE='G83046', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950495393, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='07Q', PRACTICE='G84607', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950555947, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='08A', PRACTICE='G83019', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950631351, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='08A', PRACTICE='Y02974', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950661755, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='08J', PRACTICE='H84062', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950683171, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='08K', PRACTICE='G85100', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950714221, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='08L', PRACTICE='G85089', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950762497, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='08Q', PRACTICE='G85029', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950815785, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='08Q', PRACTICE='G85082', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=42950826214, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='08T', PRACTICE='H85686', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=4, NIC=7.96, ACT_COST=7.84, QUANTITY=28, PRESCRIPTION_ID=51539641220, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q63', PCT='08X', PRACTICE='H85007', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=28, NIC=55.72, ACT_COST=54.87, QUANTITY=196, PRESCRIPTION_ID=51539651448, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q64', PCT='11M', PRACTICE='L84011', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=4, NIC=7.96, ACT_COST=7.84, QUANTITY=28, PRESCRIPTION_ID=51539739065, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q64', PCT='99N', PRACTICE='J83011', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=51539879083, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q65', PCT='15C', PRACTICE='L81013', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=4, NIC=15.96, ACT_COST=15.26, QUANTITY=56, PRESCRIPTION_ID=51540044440, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q65', PCT='15C', PRACTICE='L81026', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=4, NIC=47.82, ACT_COST=44.44, QUANTITY=168, PRESCRIPTION_ID=51540061767, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q65', PCT='15C', PRACTICE='L81106', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=51540133360, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q66', PCT='99P', PRACTICE='L83041', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=51540294774, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='09C', PRACTICE='G82142', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=51540468871, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='09J', PRACTICE='G82122', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.8, QUANTITY=56, PRESCRIPTION_ID=51540522657, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='09J', PRACTICE='G82185', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=51540525828, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='09W', PRACTICE='G82014', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=51540547367, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='10A', PRACTICE='G82684', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=51540637153, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='10D', PRACTICE='G82791', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=13, NIC=151.43, ACT_COST=140.72, QUANTITY=532, PRESCRIPTION_ID=51540662310, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='10E', PRACTICE='G82066', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=51540673216, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='10E', PRACTICE='G82796', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=51540688626, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='99J', PRACTICE='G82025', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=51540700739, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q67', PCT='99J', PRACTICE='G82135', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=51540739706, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q68', PCT='09G', PRACTICE='H82039', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=60129629704, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q68', PCT='09Y', PRACTICE='H81007', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=15.94, ACT_COST=14.82, QUANTITY=56, PRESCRIPTION_ID=60129825359, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q68', PCT='09Y', PRACTICE='H81095', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=60129857094, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q68', PCT='09Y', PRACTICE='H81122', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=5, NIC=23.93, ACT_COST=22.67, QUANTITY=84, PRESCRIPTION_ID=60129860187, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q68', PCT='99H', PRACTICE='H81080', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=60129902230, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q69', PCT='10Q', PRACTICE='K84024', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=60129988082, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q69', PCT='10Q', PRACTICE='K84047', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=60130019313, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q69', PCT='14Y', PRACTICE='K82023', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=2, NIC=31.88, ACT_COST=29.62, QUANTITY=112, PRESCRIPTION_ID=60130077468, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q69', PCT='14Y', PRACTICE='K82053', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=60130108316, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q69', PCT='15D', PRACTICE='K81020', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=23.91, ACT_COST=22.21, QUANTITY=84, PRESCRIPTION_ID=60130202500, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q70', PCT='11A', PRACTICE='J82132', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=60130498056, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q70', PCT='11J', PRACTICE='J81047', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=60130581058, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q70', PCT='11J', PRACTICE='J81072', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=60130612618, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q70', PCT='99M', PRACTICE='H81615', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=7.97, ACT_COST=7.41, QUANTITY=28, PRESCRIPTION_ID=60130657138, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA'),
#  Row(SHA='Q70', PCT='99M', PRACTICE='J82049', BNF_CODE='0202040T0AAAAAA', BNF_NAME='Spironol/Furosemide_Cap 50mg/20mg', ITEMS=1, NIC=15.94, ACT_COST=14.81, QUANTITY=56, PRESCRIPTION_ID=60130660258, YEAR=2018, MONTH=12, BNF_CHAPTER_CODE='02', BNF_SECTION_CODE='0202', BNF_PARAGRAPH_CODE='020204', BNF_SUBPARAGRAPH_CODE='0202040', BNF_CHEMICAL_CODE='0202040T0', BNF_PRODUCT_CODE='0202040T0AA')]

# %%
chemicals.count()
# Out:
# 3481
